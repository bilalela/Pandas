# %% [markdown]
# <a href="https://colab.research.google.com/github/bilalela/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #  series

# %%
series1 = {
                         'bilal' : 22,
                         'ömer ': 33,
                         'zeynep ':25
}
print(pd.Series(data = series1))
print(series1.keys())
print(series1.values())
# Out:
# bilal      22
# ömer       33
# zeynep     25
# dtype: int64
# dict_keys(['bilal', 'ömer ', 'zeynep '])
# dict_values([22, 33, 25])

# %%
q1 = {'brezilya': 200, 'türiye': 200 , 'almanya': 400}
q2 = {'brezilya':250 ,'türiye' : 700 ,'çin': 500}

# %%
seriesq1 =pd.Series(q1)
seriesq2 =pd.Series(q2)

# %%
print( seriesq1 + seriesq2)
print (seriesq1.add(seriesq2 , fill_value=0))
# Out:
# almanya       NaN
# brezilya    450.0
# türiye      900.0
# çin           NaN
# dtype: float64
# almanya     400.0
# brezilya    450.0
# türiye      900.0
# çin         500.0
# dtype: float64

# %%
my_idx = ['bilal','ömer','fatma']
my_colum =['sinav_1','sinav_2','sinav_3']
my_data = np.random.randint(50,100,(3,3))

# %% [markdown]
# ## DataFrame

# %%
my_data = np.random.randint(0,101, (5,4))
print(pd.DataFrame(my_data))
# Out:
#     0   1   2   3
# 0  92  35  62  89
# 1  31  92  78  76
# 2  84  46  73  22
# 3  75  11  22  79
# 4  54  21  12  78

# %%
my_idx = ['TR','BR','USA','RU']
my_cols = ['jan','feb','march']
my_data = np.random.randint(50,150,(4,3))

# %%
print(pd.DataFrame(my_data,my_idx,my_cols))
# Out:
#      jan  feb  march
# TR    60   76     68
# BR   110   80     88
# USA   98   77     88
# RU    85   97    142

# %%
my_colum
# Out:
# ['sinav_1', 'sinav_2', 'sinav_3']

# %%
my_idx
# Out:
# ['bilal', 'ömer', 'fatma']

# %%
my_data
# Out:
# array([[65, 50, 70],
#        [66, 82, 99],
#        [55, 73, 58]])

# %%
notlar = pd.DataFrame(data = my_data ,index= my_idx, columns= my_colum)
notlar
# Out:
#        sinav_1  sinav_2  sinav_3
# bilal       65       50       70
# ömer        66       82       99
# fatma       55       73       58

# %%
# dosya okuma >>>>>> pd.read_csv ile yapılır

# %%
df1 = pd.read_csv('cal.csv')
df1
# Out:
#             Code                                    Birthplace  \
# 0           0001                                        At sea
# 1           1000  Oceania and Antarctica (not further defined)
# 2           1101                                     Australia
# 3           1102                                Norfolk Island
# 4           1199           Australian External Territories nec
# ..           ...                                           ...
# 273         9299                  Southern and East Africa nec
# 274         0000                        Inadequately described
# 275         9999                                    Not stated
# 276  TotalStated                                  Total stated
# 277        Total                                         Total
#
#      Census_night_population_count  Census_usually_resident_population_count
# 0                               15                                        15
# ...

# %%
df1.shape
# Out:
# (278, 4)

# %%
df1.head(3) #baştaki istenilen verileri getirir
# Out:
#    Code                                    Birthplace  \
# 0  0001                                        At sea
# 1  1000  Oceania and Antarctica (not further defined)
# 2  1101                                     Australia
#
#    Census_night_population_count  Census_usually_resident_population_count
# 0                             15                                        15
# 1                              0                                         0
# 2                          83622                                     75696

# %%
df1.tail(4)  # sondan istediğimiz veri sayısını getirir
# Out:
#             Code              Birthplace  Census_night_population_count  \
# 274         0000  Inadequately described                            921
# 275         9999              Not stated                          59376
# 276  TotalStated            Total stated                        4733061
# 277        Total                   Total                        4793358
#
#      Census_usually_resident_population_count
# 274                                       432
# 275                                     57426
# 276                                   4641897
# 277                                   4699755

# %%
df1.sample(5)  # rastgele istediğim kaç tan veri varsa oları getirir
# Out:
#      Code                             Birthplace  \
# 95   4100     North Africa (not further defined)
# 84   3301                                Belarus
# 212  8423                               St Lucia
# 51   2400  Northern Europe (not further defined)
# 186  8301                                 Belize
#
#      Census_night_population_count  Census_usually_resident_population_count
# 95                               3                                         3
# 84                             354                                       333
# 212                             24                                        21
# 51                               0                                         0
# 186                             18                                        15

# %%
df1.info()  # bu metod veriler ile ilgili genel bir bilgi verir
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 4 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Code                                      278 non-null    object
#  1   Birthplace                                278 non-null    object
#  2   Census_night_population_count             278 non-null    int64
#  3   Census_usually_resident_population_count  278 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 8.8+ KB

# %%
df1.describe() #bu metod numaric olan sütünlar ile ilgili genel bir bilgi verir  ( max değer, standart sampa ,ortalama  vb.)
# Out:
#        Census_night_population_count  Census_usually_resident_population_count
# count                   2.780000e+02                              2.780000e+02
# mean                    5.151011e+04                              5.050866e+04
# std                     4.503265e+05                              4.431238e+05
# min                     0.000000e+00                              0.000000e+00
# 25%                     1.800000e+01                              1.500000e+01
# 50%                     1.755000e+02                              1.710000e+02
# 75%                     1.581000e+03                              1.462500e+03
# max                     4.793358e+06                              4.699755e+06

# %% [markdown]
# #Sütun İşlemleri

# %%
df1['Birthplace']
# Out:
# 0                                            At sea
# 1      Oceania and Antarctica (not further defined)
# 2                                         Australia
# 3                                    Norfolk Island
# 4               Australian External Territories nec
#                            ...
# 273                    Southern and East Africa nec
# 274                          Inadequately described
# 275                                      Not stated
# 276                                    Total stated
# 277                                           Total
# Name: Birthplace, Length: 278, dtype: object

# %%
df1
# Out:
#             Code                                    Birthplace  \
# 0           0001                                        At sea
# 1           1000  Oceania and Antarctica (not further defined)
# 2           1101                                     Australia
# 3           1102                                Norfolk Island
# 4           1199           Australian External Territories nec
# ..           ...                                           ...
# 273         9299                  Southern and East Africa nec
# 274         0000                        Inadequately described
# 275         9999                                    Not stated
# 276  TotalStated                                  Total stated
# 277        Total                                         Total
#
#      Census_night_population_count  Census_usually_resident_population_count
# 0                               15                                        15
# ...

# %%
df1['Census_night_population_count'] + df1['Census_usually_resident_population_count'] # Numaric iki sütun toplanabilir
# Out:
# 0           30
# 1            0
# 2       159318
# 3          222
# 4            0
#         ...
# 273          0
# 274       1353
# 275     116802
# 276    9374958
# 277    9493113
# Length: 278, dtype: int64

# %%
df1['toplam veri'] = df1['Census_night_population_count'] + df1['Census_usually_resident_population_count']
df1.head(3)  # verilere toplam veri adındaki yeni bir sütun eklemiş oldum böylece
# Out:
#    Code                                    Birthplace  \
# 0  0001                                        At sea
# 1  1000  Oceania and Antarctica (not further defined)
# 2  1101                                     Australia
#
#    Census_night_population_count  Census_usually_resident_population_count  \
# 0                             15                                        15
# 1                              0                                         0
# 2                          83622                                     75696
#
#    toplam veri
# 0           30
# 1            0
# 2       159318

# %%
df1.drop('Birthplace' ,axis=1) # silinmesini istediğim sütunu siler ((,inplace = Tru) eklenirse de silme işlemi kalıcı olaur)
# Out:
#             Code  Census_night_population_count  \
# 0           0001                             15
# 1           1000                              0
# 2           1101                          83622
# 3           1102                            114
# 4           1199                              0
# ..           ...                            ...
# 273         9299                              0
# 274         0000                            921
# 275         9999                          59376
# 276  TotalStated                        4733061
# 277        Total                        4793358
#
#      Census_usually_resident_population_count  toplam veri
# 0                                          15           30
# 1                                           0            0
# 2                                       75696       159318
# 3                                         108          222
# 4                                           0            0
# ...

# %%
df1.drop(['Birthplace' , 'toplam veri'], axis=1)
# Out:
#             Code  Census_night_population_count  \
# 0           0001                             15
# 1           1000                              0
# 2           1101                          83622
# 3           1102                            114
# 4           1199                              0
# ..           ...                            ...
# 273         9299                              0
# 274         0000                            921
# 275         9999                          59376
# 276  TotalStated                        4733061
# 277        Total                        4793358
#
#      Census_usually_resident_population_count
# 0                                          15
# 1                                           0
# 2                                       75696
# 3                                         108
# 4                                           0
# ..                                        ...
# 273                                         0
# ...

# %% [markdown]
# # Satır İşlemler
# Satır çekmek için .loc ve .iloc(intiger konumu) metodları ile yapılır
# Tabi bu işlem için genelde bir sütunu index e çeviririz

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=278, step=1)

# %%
df1.head(3)
# Out:
#                                         Birthplace  \
# Code
# 0001                                        At sea
# 1000  Oceania and Antarctica (not further defined)
# 1101                                     Australia
#
#       Census_night_population_count  Census_usually_resident_population_count  \
# Code
# 0001                             15                                        15
# 1000                              0                                         0
# 1101                          83622                                     75696
#
#       toplam veri
# Code
# 0001           30
# 1000            0
# 1101       159318

# %%
df1.set_index('Birthplace',drop= True,inplace=True) # böylece hem bir sütunu index e çevirdim hem düşürdüm hemde kalıcı olarak düşürdüm
df1.head(3)
# Out:
#                                               Census_night_population_count  \
# Birthplace
# At sea                                                                   15
# Oceania and Antarctica (not further defined)                              0
# Australia                                                             83622
#
#                                               Census_usually_resident_population_count  \
# Birthplace
# At sea                                                                              15
# Oceania and Antarctica (not further defined)                                         0
# Australia                                                                        75696
#
#                                               toplam veri
# Birthplace
# At sea                                                 30
# Oceania and Antarctica (not further defined)            0
# Australia                                          159318

# %%
df1.iloc[0]  # birinci satırı getirir
# Out:
# Census_night_population_count               15
# Census_usually_resident_population_count    15
# toplam veri                                 30
# Name: At sea, dtype: int64

# %%
df1.loc['At sea']
# Out:
# Census_night_population_count               15
# Census_usually_resident_population_count    15
# toplam veri                                 30
# Name: At sea, dtype: int64

# %% [markdown]
# # DataFram de sorgu işlemleri
